# %%
import os
num_threads = "8"
os.environ["OMP_NUM_THREADS"] = num_threads
os.environ["OPENBLAS_NUM_THREADS"] = num_threads
os.environ["MKL_NUM_THREADS"] = num_threads
os.environ["VECLIB_MAXIMUM_THREADS"] = num_threads
os.environ["NUMEXPR_NUM_THREADS"] = num_threads

# %%
import matplotlib.pyplot as plt
import torch
from torch.autograd import grad, Variable
import autograd
import autograd.numpy as np
import copy
import scipy as sp
from scipy import stats
from sklearn import metrics
import sys
import ot
import gwot
from gwot import models, sim, ts, util
import gwot.bridgesampling as bs
import dcor

sys.path.append("fig1_batch")
import importlib
import models
import random
import model_fig1 as model_sim

# %%
importlib.reload(model_sim)
# Out:
# <module 'model_fig1' from '/Users/Viresh/Desktop/Spring 2025/AI4TS/ATD-NSF/trajectory-inference/mfl/fig1_batch/model_fig1.py'>

# %%
device = torch.device("cpu") # torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

# %%
PLT_CELL = 2.5

# %%
# set random seed
SRAND = 0
torch.manual_seed(SRAND)
np.random.seed(SRAND)

# %%
M = 100
N_vals = [64, 1]
N0 = 64

# setup simulation object
sims_all = [gwot.sim.Simulation(V = model_sim.Psi, dV = model_sim.dPsi, birth_death = False, 
                          N = np.array([N0, ] + [N, ]*(model_sim.T-2) + [N0, ]),
                          T = model_sim.T, 
                          d = model_sim.dim, 
                          D = model_sim.D, 
                          t_final = model_sim.t_final, 
                          ic_func = model_sim.ic_func, 
                          pool = None) for N in N_vals]

# sample from simulation
for s in sims_all:
    s.sample(steps_scale = int(model_sim.sim_steps/s.T));

# %%
sim_gt = copy.deepcopy(sims_all[0])
sim_gt.N = np.array([500, ]*model_sim.T)
sim_gt.sample(steps_scale = int(model_sim.sim_steps/sims_all[0].T));

# %%
# plot samples
i = 0
plt.scatter(sims_all[i].x[:, 0], sims_all[i].x[:, 1], alpha = 0.25, c = sims_all[i].t_idx)

# %%
plt.scatter(sim_gt.x[:, 0], sim_gt.x[:, 1], alpha = 0.25, c = sim_gt.t_idx)

# %%
k = 0
plt.subplot(1, 2, 1)
plt.scatter(np.linspace(0, model_sim.t_final, model_sim.T)[sims_all[-1].t_idx], sims_all[-1].x[:, k], alpha = 0.5, color = "red")
plt.ylim(-2.0, 2.0)
plt.subplot(1, 2, 2)
plt.scatter(np.linspace(0, model_sim.t_final, model_sim.T)[sim_gt.t_idx], sim_gt.x[:, k], alpha = 0.01, color = "blue")
plt.ylim(-2.0, 2.0)
# Out:
# (-2.0, 2.0)

# %%
importlib.reload(models)
importlib.reload(model_sim)
torch.set_num_threads(8)

# %%
models_all = [models.TrajLoss(torch.randn(model_sim.T, M, model_sim.dim)*0.1,
                        torch.tensor(s.x, device = device), 
                        torch.tensor(s.t_idx, device = device), 
                        dt = model_sim.t_final/model_sim.T, tau = model_sim.D, sigma = None, M = M,
                        lamda_reg = 0.05, lamda_cst = 0, sigma_cst = float("Inf"),
                        branching_rate_fn = model_sim.branching_rate,
                        sinkhorn_iters = 250, device = device, warm_start = True) for s in sims_all]

# %%
outputs_all = [models.optimize(m, n_iter = 2_500, eta_final = 0.1, tau_final = model_sim.D, sigma_final = 0.5, N = M, temp_init = 1.0, temp_ratio = 1.0, dim = model_sim.dim, tloss = m, print_interval = 50) for m in models_all]
# Out:
# Iteration 0, Loss = 2.372, Primal loss = 4.342, Avg. iters = 1.889, eta = 0.100, temp = 1.000
# Iteration 50, Loss = 1.121, Primal loss = 2.574, Avg. iters = 22.000, eta = 0.100, temp = 1.000
# Iteration 100, Loss = 0.952, Primal loss = 2.418, Avg. iters = 19.889, eta = 0.100, temp = 1.000
# Iteration 150, Loss = 0.891, Primal loss = 2.353, Avg. iters = 19.889, eta = 0.100, temp = 1.000
# Iteration 200, Loss = 0.842, Primal loss = 2.331, Avg. iters = 26.222, eta = 0.100, temp = 1.000
# Iteration 250, Loss = 0.805, Primal loss = 2.323, Avg. iters = 19.333, eta = 0.100, temp = 1.000
# Iteration 300, Loss = 0.786, Primal loss = 2.303, Avg. iters = 23.889, eta = 0.100, temp = 1.000
# Iteration 350, Loss = 0.762, Primal loss = 2.304, Avg. iters = 18.000, eta = 0.100, temp = 1.000
# Iteration 400, Loss = 0.768, Primal loss = 2.299, Avg. iters = 22.111, eta = 0.100, temp = 1.000
# Iteration 450, Loss = 0.740, Primal loss = 2.293, Avg. iters = 12.222, eta = 0.100, temp = 1.000
# Iteration 500, Loss = 0.745, Primal loss = 2.297, Avg. iters = 20.889, eta = 0.100, temp = 1.000
# Iteration 550, Loss = 0.747, Primal loss = 2.292, Avg. iters = 22.111, eta = 0.100, temp = 1.000
# Iteration 600, Loss = 0.743, Primal loss = 2.298, Avg. iters = 19.667, eta = 0.100, temp = 1.000
# Iteration 650, Loss = 0.727, Primal loss = 2.289, Avg. iters = 19.000, eta = 0.100, temp = 1.000
# Iteration 700, Loss = 0.729, Primal loss = 2.298, Avg. iters = 22.222, eta = 0.100, temp = 1.000
# Iteration 750, Loss = 0.727, Primal loss = 2.282, Avg. iters = 12.000, eta = 0.100, temp = 1.000
# Iteration 800, Loss = 0.714, Primal loss = 2.286, Avg. iters = 17.778, eta = 0.100, temp = 1.000
# Iteration 850, Loss = 0.718, Primal loss = 2.283, Avg. iters = 8.222, eta = 0.100, temp = 1.000
# Iteration 900, Loss = 0.725, Primal loss = 2.283, Avg. iters = 6.000, eta = 0.100, temp = 1.000
# Iteration 950, Loss = 0.716, Primal loss = 2.299, Avg. iters = 9.667, eta = 0.100, temp = 1.000
# Iteration 1000, Loss = 0.698, Primal loss = 2.287, Avg. iters = 4.667, eta = 0.100, temp = 1.000
# Iteration 1050, Loss = 0.706, Primal loss = 2.282, Avg. iters = 5.333, eta = 0.100, temp = 1.000
# Iteration 1100, Loss = 0.718, Primal loss = 2.299, Avg. iters = 5.222, eta = 0.100, temp = 1.000
# Iteration 1150, Loss = 0.726, Primal loss = 2.307, Avg. iters = 4.889, eta = 0.100, temp = 1.000
# Iteration 1200, Loss = 0.712, Primal loss = 2.289, Avg. iters = 5.000, eta = 0.100, temp = 1.000
# Iteration 1250, Loss = 0.714, Primal loss = 2.286, Avg. iters = 8.333, eta = 0.100, temp = 1.000
# Iteration 1300, Loss = 0.706, Primal loss = 2.285, Avg. iters = 9.778, eta = 0.100, temp = 1.000
# Iteration 1350, Loss = 0.715, Primal loss = 2.300, Avg. iters = 6.222, eta = 0.100, temp = 1.000
# Iteration 1400, Loss = 0.729, Primal loss = 2.284, Avg. iters = 4.556, eta = 0.100, temp = 1.000
# Iteration 1450, Loss = 0.733, Primal loss = 2.288, Avg. iters = 8.556, eta = 0.100, temp = 1.000
# Iteration 1500, Loss = 0.724, Primal loss = 2.278, Avg. iters = 4.333, eta = 0.100, temp = 1.000
# Iteration 1550, Loss = 0.721, Primal loss = 2.288, Avg. iters = 4.889, eta = 0.100, temp = 1.000
# Iteration 1600, Loss = 0.708, Primal loss = 2.284, Avg. iters = 7.889, eta = 0.100, temp = 1.000
# Iteration 1650, Loss = 0.729, Primal loss = 2.289, Avg. iters = 10.778, eta = 0.100, temp = 1.000
# Iteration 1700, Loss = 0.734, Primal loss = 2.287, Avg. iters = 4.889, eta = 0.100, temp = 1.000
# Iteration 1750, Loss = 0.713, Primal loss = 2.296, Avg. iters = 7.222, eta = 0.100, temp = 1.000
# Iteration 1800, Loss = 0.700, Primal loss = 2.292, Avg. iters = 9.111, eta = 0.100, temp = 1.000
# Iteration 1850, Loss = 0.709, Primal loss = 2.281, Avg. iters = 15.333, eta = 0.100, temp = 1.000
# Iteration 1900, Loss = 0.713, Primal loss = 2.282, Avg. iters = 7.222, eta = 0.100, temp = 1.000
# Iteration 1950, Loss = 0.714, Primal loss = 2.283, Avg. iters = 7.889, eta = 0.100, temp = 1.000
# Iteration 2000, Loss = 0.702, Primal loss = 2.286, Avg. iters = 4.000, eta = 0.100, temp = 1.000
# Iteration 2050, Loss = 0.698, Primal loss = 2.294, Avg. iters = 6.222, eta = 0.100, temp = 1.000
# Iteration 2100, Loss = 0.699, Primal loss = 2.278, Avg. iters = 4.111, eta = 0.100, temp = 1.000
# Iteration 2150, Loss = 0.702, Primal loss = 2.287, Avg. iters = 4.444, eta = 0.100, temp = 1.000
# Iteration 2200, Loss = 0.740, Primal loss = 2.297, Avg. iters = 6.222, eta = 0.100, temp = 1.000
# Iteration 2250, Loss = 0.734, Primal loss = 2.297, Avg. iters = 5.556, eta = 0.100, temp = 1.000
# Iteration 2300, Loss = 0.711, Primal loss = 2.291, Avg. iters = 9.556, eta = 0.100, temp = 1.000
# Iteration 2350, Loss = 0.711, Primal loss = 2.288, Avg. iters = 11.444, eta = 0.100, temp = 1.000
# Iteration 2400, Loss = 0.725, Primal loss = 2.298, Avg. iters = 12.333, eta = 0.100, temp = 1.000
# Iteration 2450, Loss = 0.721, Primal loss = 2.290, Avg. iters = 6.000, eta = 0.100, temp = 1.000
# Iteration 0, Loss = 2.771, Primal loss = 4.738, Avg. iters = 2.000, eta = 0.100, temp = 1.000
# Iteration 50, Loss = 0.806, Primal loss = 2.160, Avg. iters = 24.444, eta = 0.100, temp = 1.000
# Iteration 100, Loss = 0.778, Primal loss = 2.058, Avg. iters = 24.667, eta = 0.100, temp = 1.000
# Iteration 150, Loss = 0.704, Primal loss = 1.979, Avg. iters = 45.000, eta = 0.100, temp = 1.000
# Iteration 200, Loss = 0.676, Primal loss = 1.949, Avg. iters = 41.000, eta = 0.100, temp = 1.000
# Iteration 250, Loss = 0.655, Primal loss = 1.933, Avg. iters = 32.000, eta = 0.100, temp = 1.000
# Iteration 300, Loss = 0.649, Primal loss = 1.920, Avg. iters = 45.778, eta = 0.100, temp = 1.000
# Iteration 350, Loss = 0.593, Primal loss = 1.894, Avg. iters = 41.000, eta = 0.100, temp = 1.000
# Iteration 400, Loss = 0.607, Primal loss = 1.874, Avg. iters = 38.889, eta = 0.100, temp = 1.000
# Iteration 450, Loss = 0.593, Primal loss = 1.880, Avg. iters = 28.111, eta = 0.100, temp = 1.000
# Iteration 500, Loss = 0.597, Primal loss = 1.874, Avg. iters = 48.556, eta = 0.100, temp = 1.000
# Iteration 550, Loss = 0.588, Primal loss = 1.870, Avg. iters = 54.889, eta = 0.100, temp = 1.000
# Iteration 600, Loss = 0.609, Primal loss = 1.883, Avg. iters = 53.111, eta = 0.100, temp = 1.000
# Iteration 650, Loss = 0.590, Primal loss = 1.866, Avg. iters = 51.111, eta = 0.100, temp = 1.000
# Iteration 700, Loss = 0.593, Primal loss = 1.876, Avg. iters = 39.667, eta = 0.100, temp = 1.000
# Iteration 750, Loss = 0.588, Primal loss = 1.863, Avg. iters = 62.222, eta = 0.100, temp = 1.000
# Iteration 800, Loss = 0.592, Primal loss = 1.861, Avg. iters = 52.778, eta = 0.100, temp = 1.000
# Iteration 850, Loss = 0.605, Primal loss = 1.858, Avg. iters = 51.889, eta = 0.100, temp = 1.000
# Iteration 900, Loss = 0.576, Primal loss = 1.857, Avg. iters = 38.111, eta = 0.100, temp = 1.000
# Iteration 950, Loss = 0.587, Primal loss = 1.875, Avg. iters = 34.222, eta = 0.100, temp = 1.000
# Iteration 1000, Loss = 0.561, Primal loss = 1.867, Avg. iters = 26.889, eta = 0.100, temp = 1.000
# Iteration 1050, Loss = 0.571, Primal loss = 1.872, Avg. iters = 36.333, eta = 0.100, temp = 1.000
# Iteration 1100, Loss = 0.570, Primal loss = 1.874, Avg. iters = 42.000, eta = 0.100, temp = 1.000
# Iteration 1150, Loss = 0.560, Primal loss = 1.865, Avg. iters = 37.778, eta = 0.100, temp = 1.000
# Iteration 1200, Loss = 0.565, Primal loss = 1.864, Avg. iters = 39.889, eta = 0.100, temp = 1.000
# Iteration 1250, Loss = 0.573, Primal loss = 1.864, Avg. iters = 30.889, eta = 0.100, temp = 1.000
# Iteration 1300, Loss = 0.579, Primal loss = 1.872, Avg. iters = 62.778, eta = 0.100, temp = 1.000
# Iteration 1350, Loss = 0.571, Primal loss = 1.861, Avg. iters = 40.556, eta = 0.100, temp = 1.000
# Iteration 1400, Loss = 0.569, Primal loss = 1.862, Avg. iters = 36.778, eta = 0.100, temp = 1.000
# Iteration 1450, Loss = 0.561, Primal loss = 1.864, Avg. iters = 35.778, eta = 0.100, temp = 1.000
# Iteration 1500, Loss = 0.540, Primal loss = 1.874, Avg. iters = 49.444, eta = 0.100, temp = 1.000
# Iteration 1550, Loss = 0.557, Primal loss = 1.864, Avg. iters = 33.222, eta = 0.100, temp = 1.000
# Iteration 1600, Loss = 0.536, Primal loss = 1.866, Avg. iters = 40.778, eta = 0.100, temp = 1.000
# Iteration 1650, Loss = 0.530, Primal loss = 1.870, Avg. iters = 23.333, eta = 0.100, temp = 1.000
# Iteration 1700, Loss = 0.539, Primal loss = 1.854, Avg. iters = 28.333, eta = 0.100, temp = 1.000
# Iteration 1750, Loss = 0.548, Primal loss = 1.876, Avg. iters = 45.222, eta = 0.100, temp = 1.000
# Iteration 1800, Loss = 0.539, Primal loss = 1.868, Avg. iters = 37.111, eta = 0.100, temp = 1.000
# Iteration 1850, Loss = 0.545, Primal loss = 1.856, Avg. iters = 43.667, eta = 0.100, temp = 1.000
# Iteration 1900, Loss = 0.549, Primal loss = 1.855, Avg. iters = 37.444, eta = 0.100, temp = 1.000
# Iteration 1950, Loss = 0.533, Primal loss = 1.868, Avg. iters = 20.667, eta = 0.100, temp = 1.000
# Iteration 2000, Loss = 0.561, Primal loss = 1.858, Avg. iters = 25.778, eta = 0.100, temp = 1.000
# Iteration 2050, Loss = 0.538, Primal loss = 1.868, Avg. iters = 35.000, eta = 0.100, temp = 1.000
# Iteration 2100, Loss = 0.544, Primal loss = 1.860, Avg. iters = 26.111, eta = 0.100, temp = 1.000
# Iteration 2150, Loss = 0.541, Primal loss = 1.871, Avg. iters = 23.222, eta = 0.100, temp = 1.000
# Iteration 2200, Loss = 0.530, Primal loss = 1.867, Avg. iters = 20.111, eta = 0.100, temp = 1.000
# Iteration 2250, Loss = 0.548, Primal loss = 1.876, Avg. iters = 26.667, eta = 0.100, temp = 1.000
# Iteration 2300, Loss = 0.541, Primal loss = 1.872, Avg. iters = 27.111, eta = 0.100, temp = 1.000
# Iteration 2350, Loss = 0.534, Primal loss = 1.875, Avg. iters = 21.333, eta = 0.100, temp = 1.000
# Iteration 2400, Loss = 0.523, Primal loss = 1.870, Avg. iters = 22.667, eta = 0.100, temp = 1.000
# Iteration 2450, Loss = 0.551, Primal loss = 1.877, Avg. iters = 32.333, eta = 0.100, temp = 1.000

# %%
plt.plot(outputs_all[0][1])

# %%
plt.plot(np.vstack([o[1] for o in outputs_all]).T)
plt.title("Objective: primal")
# Out:
# Text(0.5, 1.0, 'Objective: primal')

# %%
u = np.full(model_sim.dim, 1); u[2:] = 0
u = u/np.linalg.norm(u)

# %%
i = -1
with torch.no_grad():
    plt.scatter(np.kron(np.linspace(0, model_sim.t_final, model_sim.T), np.ones(M)), models_all[i].x.reshape(-1, model_sim.dim)[:, 0], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.1)
# plt.scatter(np.linspace(0, t_final, T)[simodel_sim.t_idx], np.dot(simodel_sim.x, u), alpha = 0.5, color = "red", marker = "x")

# %%
i = 0
plt.scatter(sims_all[i].x[:, 0], sims_all[i].x[:, 1], color = "red", marker = "x")
with torch.no_grad():
    plt.scatter(models_all[i].x.reshape(-1, model_sim.dim)[:, 0], models_all[i].x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25)
plt.axis('auto')
# Out:
# (np.float64(-2.056414809860224),
#  np.float64(1.9339278104148254),
#  np.float64(-1.6931091298409706),
#  np.float64(0.41073104072956595))

# %%
models_all_gwot = [gwot.models.OTModel(s, lamda_reg = 0.0025,
          eps_df = 0.01*torch.ones(s.T), 
          growth_constraint="exact", 
          pi_0 = "uniform",
          use_keops = False,
          device = device) for s in sims_all]

for m in models_all_gwot:
    m.solve_lbfgs(steps = 10, 
                    max_iter = 50, 
                    lr = 1,
                    history_size = 50, 
                    line_search_fn = 'strong_wolfe', 
                    factor = 2, 
                    tol = 1e-5, 
                    retry_max = 0);
# Out:
# /Users/Viresh/Desktop/Spring 2025/AI4TS/ATD-NSF/trajectory-inference/mfl/langevin_env_repr/lib/python3.12/site-packages/gwot/models.py:296: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3729.)
#   model.eps_df[i] * torch.exp(u/model.eps_df[i]).T @ (model.K_ij_df[i] @ torch.exp(v/model.eps_df[i]))
# Iteration =  0  Dual obj =  -0.6775450542533741  Primal_obj =  61.86420850482249  Gap =  62.541753559075865 Sum =  68.46911524280489
# Iteration =  1  Dual obj =  -0.02742865893509469  Primal_obj =  -0.027428183367292622  Gap =  4.755678020690324e-07 Sum =  0.9810323646179253
# Iteration =  0  Dual obj =  -0.6261318437521719  Primal_obj =  57.03884142549413  Gap =  57.664973269246296 Sum =  66.33025356702522
# Iteration =  1  Dual obj =  -0.0163904834374813  Primal_obj =  -0.008810527171384825  Gap =  0.0075799562660964735 Sum =  0.9540081451109245
# Iteration =  2  Dual obj =  -0.010069482919740115  Primal_obj =  -0.005290336286394227  Gap =  0.004779146633345888 Sum =  0.9768708849154709
# Iteration =  3  Dual obj =  -0.003993591017560614  Primal_obj =  -0.003649523736947838  Gap =  0.00034406728061277606 Sum =  0.9854730426318208
# Iteration =  4  Dual obj =  0.002234106035126915  Primal_obj =  0.024930653198480666  Gap =  0.02269654716335375 Sum =  0.9986395249345575
# Iteration =  5  Dual obj =  0.00555326193007185  Primal_obj =  0.0030148498730134827  Gap =  -0.002538412057058367 Sum =  0.9972122811219617
# Iteration =  6  Dual obj =  0.006597519485577366  Primal_obj =  0.0036656358960566217  Gap =  -0.0029318835895207444 Sum =  1.0012966466707818
# Iteration =  7  Dual obj =  0.007262207744363303  Primal_obj =  0.005127742343348313  Gap =  -0.0021344654010149906 Sum =  0.9999196602843881
# Iteration =  8  Dual obj =  0.007596678590222578  Primal_obj =  0.006368209660682578  Gap =  -0.0012284689295400004 Sum =  1.0005765554731791
# Iteration =  9  Dual obj =  0.00778843698984193  Primal_obj =  0.007816693931459243  Gap =  2.825694161731271e-05 Sum =  0.9998901885770728

# %%
X_gwot_samples_all = [np.stack([m.ts.x[np.random.choice(m.ts.x.shape[0], size = M, p = torch.nn.functional.normalize(m.get_R(t).detach(), p = 1.0, dim = 0)), :] for t in range(model_sim.T)]) for m in models_all_gwot]

# %%
N_paths_gt = 250
N_paths = 50
paths_gt = sim_gt.sample_trajectory(steps_scale = int(model_sim.sim_steps/sim_gt.T), N = N_paths_gt)

# %%
from matplotlib.gridspec import GridSpec
fig = plt.figure(figsize = (3*PLT_CELL, 2*PLT_CELL))
gs = GridSpec(2, 3, figure=fig)

for (i, s) in enumerate(sims_all):
    ax = fig.add_subplot(gs[len(models_all)-i-1, 0])
    # plt.scatter(np.linspace(0, t_final, T)[s.t_idx], np.dot(s.x, u), alpha = 0.25, color = "red", marker = ".")
    # plt.plot(np.linspace(0, t_final, paths_gt.shape[1]), np.dot(paths_gt, u).T, color = 'grey', alpha = 0.05);
    ax.plot(paths_gt[:, :, 0].T, paths_gt[:, :, 1].T, color = 'grey', alpha = 0.05);
    # ax.scatter(s.x[:, 0], s.x[:, 1], alpha = 0.5, color = "red", marker = ".")
    ax.scatter(s.x[:, 0], s.x[:, 1], alpha = 0.5, c = s.t_idx/s.T, marker = ".")
    ax.set_ylim(-1.75, 0.5); ax.set_xlim(-2, 2)
    ax.set_xlabel("$x_0$"); ax.set_ylabel("$x_1$")
    # ax.set_title("N = %d" % N_vals[i])
    ax.text(0.75, 0.25, "N = %d" % N_vals[i])
    if i > 0:
        ax.set_title("Samples")
        ax.get_xaxis().set_visible(False)

for (i, m) in enumerate(models_all):
    ax = fig.add_subplot(gs[len(models_all)-i-1, 1])
    with torch.no_grad():
        paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = m.x.cpu().numpy(), 
                            get_gamma_fn = lambda i : m.loss_reg.ot_losses[i].coupling().cpu(), num_couplings = model_sim.T-1)
        # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
        ax.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
        # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(m.x.reshape(-1, dim), u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
        im = ax.scatter(m.x.reshape(-1, model_sim.dim)[:, 0], m.x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.linspace(0, model_sim.t_final, model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
    ax.set_xlabel("$x_0$"); ax.set_ylabel("$x_1$")
    ax.set_ylim(-1.75, 0.5); ax.set_xlim(-2, 2)
    # ax.set_title("N = %d" % N_vals[i])
    ax.text(0.75, 0.25, "N = %d" % N_vals[i])
    ax.get_yaxis().set_visible(False)
    if i > 0:
        ax.set_title("MFL")
        ax.get_xaxis().set_visible(False)

for (i, x) in enumerate(X_gwot_samples_all):
    ax = fig.add_subplot(gs[len(models_all)-i-1, 2])
    with torch.no_grad():
        paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = [sims_all[i].x, ]*sims_all[i].T, 
                                get_gamma_fn = lambda j : models_all_gwot[i].get_coupling_reg(j, K = models_all_gwot[i].get_K(j)), num_couplings = sims_all[i].T-1)
        # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
        ax.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
    # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(x, u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
    ax.scatter(x.reshape(-1, model_sim.dim)[:, 0], x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
    ax.set_ylim(-1.75, 0.5); ax.set_xlim(-2, 2)
    ax.set_xlabel("$x_0$"); ax.set_ylabel("$x_1$")
    # ax.set_title("N = %d" % N_vals[i])
    ax.text(0.75, 0.25, "N = %d" % N_vals[i])
    ax.get_yaxis().set_visible(False)
    if i > 0:
        ax.set_title("gWOT")
        ax.get_xaxis().set_visible(False)

plt.tight_layout() 
        
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.925, 0.15, 0.025, 0.7])
cb = fig.colorbar(im, cax=cbar_ax)
cb.set_alpha(1)
# cb.draw_all()
cbar_ax.set_title("$t$")
 
plt.savefig("fig1_langevin_new.pdf")

# %%
N_paths = 50
plt.figure(figsize = (3*PLT_CELL, 1.25*PLT_CELL))
for (i, m) in enumerate(models_all):
    plt.subplot(1, len(N_vals), i+1)
    with torch.no_grad():
        paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = m.x.cpu().numpy(), 
                            get_gamma_fn = lambda i : m.loss_reg.ot_losses[i].coupling().cpu(), num_couplings = model_sim.T-1)
        # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
        plt.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
        # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(m.x.reshape(-1, dim), u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
        plt.scatter(m.x.reshape(-1, model_sim.dim)[:, 0], m.x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
    plt.xlabel("x"); plt.ylabel("y")
    plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
    plt.title("N = %d" % N_vals[i])
    if i > 0:
        plt.gca().get_yaxis().set_visible(False)
plt.suptitle("Langevin")
plt.tight_layout()
plt.savefig("fig1_langevin.pdf")

# %%
plt.figure(figsize = (3*PLT_CELL, 1.25*PLT_CELL))
for (i, x) in enumerate(X_gwot_samples_all):
    plt.subplot(1, len(N_vals), i+1)
    with torch.no_grad():
        paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = [sims_all[i].x, ]*sims_all[i].T, 
                                get_gamma_fn = lambda j : models_all_gwot[i].get_coupling_reg(j, K = models_all_gwot[i].get_K(j)), num_couplings = sims_all[i].T-1)
        # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
        plt.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
    # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(x, u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
    plt.scatter(x.reshape(-1, model_sim.dim)[:, 0], x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
    plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
    plt.xlabel("x"); plt.ylabel("y")
    if i > 0:
        plt.gca().get_yaxis().set_visible(False)
    plt.title("N = %d" % N_vals[i])
plt.suptitle("gWOT")
plt.tight_layout()
plt.savefig("fig1_gwot.pdf")

# %%
plt.figure(figsize = (3*PLT_CELL, 1.25*PLT_CELL))
for (i, s) in enumerate(sims_all):
    plt.subplot(1, len(N_vals), i+1)
    # plt.scatter(np.linspace(0, t_final, T)[s.t_idx], np.dot(s.x, u), alpha = 0.25, color = "red", marker = ".")
    # plt.plot(np.linspace(0, t_final, paths_gt.shape[1]), np.dot(paths_gt, u).T, color = 'grey', alpha = 0.05);
    plt.plot(paths_gt[:, :, 0].T, paths_gt[:, :, 1].T, color = 'grey', alpha = 0.05);
    plt.scatter(s.x[:, 0], s.x[:, 1], alpha = 0.5, color = "red", marker = ".")
    plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
    if i > 0:
        plt.gca().get_yaxis().set_visible(False)
    plt.xlabel("x"); plt.ylabel("y")
    plt.title("N = %d" % N_vals[i])
plt.suptitle("Samples")
plt.tight_layout()
plt.savefig("fig1_samples.pdf")

# %%
plt.figure(figsize = (3*PLT_CELL, PLT_CELL))
i = 1

plt.subplot(1, 4, 1)
plt.plot(paths_gt[:, :, 0].T, paths_gt[:, :, 1].T, color = 'grey', alpha = 0.05);
plt.scatter(sim_gt.x[:, 0], sim_gt.x[:, 1], alpha = 0.025, color = "blue", marker = ".")
plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
plt.xlabel("x"); plt.ylabel("y")
plt.title("Ground truth")

plt.subplot(1, 4, 2)
plt.plot(paths_gt[:, :, 0].T, paths_gt[:, :, 1].T, color = 'grey', alpha = 0.05);
plt.scatter(sims_all[i].x[:, 0], sims_all[i].x[:, 1], alpha = 0.5, color = "red", marker = ".")
plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
plt.xlabel("x")
plt.title("Samples")
plt.gca().get_yaxis().set_visible(False)

plt.subplot(1, 4, 3)
with torch.no_grad():
    paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = m.x.cpu().numpy(), 
                        get_gamma_fn = lambda i : m.loss_reg.ot_losses[i].coupling().cpu(), num_couplings = model_sim.T-1)
    # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
    plt.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
    # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(m.x.reshape(-1, dim), u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
    plt.scatter(m.x.reshape(-1, model_sim.dim)[:, 0], m.x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
plt.xlabel("x")
plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
plt.title("Reconstruction")
plt.gca().get_yaxis().set_visible(False)

plt.tight_layout()

# plt.subplot(1, 4, 4)
# with torch.no_grad():
#     paths = bs.sample_paths(None, N = N_paths, coord = True, x_all = [sims_all[i].x, ]*sims_all[i].T, 
#                             get_gamma_fn = lambda j : models_all_gwot[i].get_coupling_reg(j, K = models_all_gwot[i].get_K(j)), num_couplings = sims_all[i].T-1)
#     # plt.plot(np.linspace(0, t_final, paths.shape[1]), np.dot(paths, u).T, color = 'grey', alpha = 0.1);
#     plt.plot(paths[:, :, 0].T, paths[:, :, 1].T, color = 'grey', alpha = 0.25);
# # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(x, u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.25, marker = ".")
# plt.scatter(x.reshape(-1, model_sim.dim)[:, 0], x.reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.arange(model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
# plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
# plt.gca().get_yaxis().set_visible(False)

# %%
fig = plt.figure(figsize = (3.5*PLT_CELL, 1*PLT_CELL))
for (i, j) in enumerate(np.array([1, 50, 500, 2500])-1):
    plt.subplot(1, 4, i+1)
    # plt.scatter(np.kron(np.linspace(0, t_final, T), np.ones(M)), np.dot(outputs_all[0][2][j, :, :, :].reshape(-1, dim), u), c = np.kron(np.arange(T), np.ones(M)), alpha = 0.1, marker = '.')
    im = plt.scatter(outputs_all[0][2][j, :, :, :].reshape(-1, model_sim.dim)[:, 0], outputs_all[0][2][j, :, :, :].reshape(-1, model_sim.dim)[:, 1], c = np.kron(np.linspace(0, model_sim.t_final, model_sim.T), np.ones(M)), alpha = 0.25, marker = ".")
    plt.ylim(-1.75, 0.5); plt.xlim(-2, 2)
    # plt.text(-1.75, -1.65, "Iter %d" % (j+1))
    plt.title("Iter %d" % (j+1))
    plt.xlabel("x")
    plt.ylabel("y")
    # if i // 4 == 0:
    #     plt.gca().get_xaxis().set_visible(False)
    if i % 4 > 0:
        plt.gca().get_yaxis().set_visible(False)
plt.tight_layout()

fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.925, 0.15, 0.025, 0.7])
cb = fig.colorbar(im, cax=cbar_ax)
cb.set_alpha(1)
cb.draw_all()
cbar_ax.set_title("$t$")

plt.savefig("fig2_trainingdynamics.pdf")

# %%
plt.figure(figsize = (PLT_CELL, PLT_CELL))
plt.plot(outputs_all[0][1], 'k')
plt.title("Reduced objective $F$")
plt.xlabel("Iteration")
plt.ylabel("$F$")
plt.tight_layout()
plt.ylim(2.25, 3.0)
plt.savefig("fig2_objective.pdf")
